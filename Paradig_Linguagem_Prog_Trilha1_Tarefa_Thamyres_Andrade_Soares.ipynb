# %% [markdown]
# <a href="https://colab.research.google.com/github/ThamyresChristine/BigData_Mackenzie/blob/main/Paradig_Linguagem_Prog_Trilha1_Tarefa_Thamyres_Andrade_Soares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aquisição dos Dados**

# %%
import urllib.request  

texto = []

for line in urllib.request.urlopen('https://raw.githubusercontent.com/ThamyresChristine/BigData_Mackenzie/main/Texto_Tarefa_Trilha_1.txt'): 
    texto.append(line.decode('utf-8'))

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','') # elimina ' e "

# %% [markdown]
# #**Construção do Dicionário**

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
  #print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'sete': 2, 'lições': 1, 'para': 34, 'ser': 15, 'produtivo': 2, 'deus': 14, 'é': 27, 'o': 61, 'grande': 3, 'criador': 5, 'supremo': 2, 'e': 86, 'ele': 17, 'criou': 4, 'os': 14, 'seres': 2, 'humanos': 2, 'à': 7, 'sua': 7, 'imagem': 3, 'como': 23, 'criadores': 4, 'secundários': 2, 'voltemos': 1, 'ao': 5, 'evangelho': 1, 'transcrição': 1, 'do': 28, 'áudio': 1, 'então': 10, 'pastor': 5, 'john': 9, 'aqui': 5, 'estamos': 2, 'nós': 3, 'depois': 1, 'de': 65, 'meses': 2, 'mais': 17, 'gravações': 1, 'vamos': 1, 'dar': 3, 'um': 42, 'passo': 1, 'atrás': 3, 'meditar': 1, 'sobre': 5, 'isso': 4, 'nos': 9, 'conte': 1, 'trabalho': 4, 'especialmente': 1, 'seu': 4, 'próprio': 1, 'as': 11, 'pessoas': 4, 'olham': 2, 'ministério': 1, 'dizem': 1, 'que': 83, 'você': 22, 'escreveu': 2, 'muito': 12, 'falou': 2, 'realizou': 1, 'aprendeu': 1, 'própria': 1, 'produtividade': 4, 'conselho': 1, 'sábio': 1, 'ou': 14, 'criatividade': 1, 'poderia': 2, 'compartilhar': 1, 'com': 26, 'a': 49, 'gente': 2, 'neste': 1, 'episódio': 3, 'piper': 8, 'responde': 5, '[piper]': 1, 'bom': 3, 'eu': 34, 'tenho': 6, 'algumas': 3, 'considerações': 2, 'mas': 10, 'vou': 2, 'deixar': 3, 'ouvintes': 2, 'julguem': 1, 'se': 22, 'são': 2, 'sábias': 1, 'não': 28, 'depende': 1, 'muitas': 2, 'tony': 5, 'sabe': 1, 'tanto': 1, 'quanto': 2, 'podcasts': 1, 'esse': 2, 'existem': 2, 'apenas': 6, 'por': 19, 'causa': 1, 'uma': 21, 'pessoa': 2, 'existiria': 2, 'selecionasse': 1, 'perguntas': 1, 'cuidasse': 1, 'da': 12, 'tecnologia': 1, 'editasse': 1, 'episódios': 8, 'fornecesse': 1, 'desiring': 3, 'god': 3, 'sem': 3, 'time': 2, 'especialistas': 2, 'em': 35, 'computadores': 1, 'no': 10, 'bem': 1, 'marketing': 1, 'creio': 5, 'primeira': 3, 'lição': 2, 'talvez': 3, 'pérola': 1, 'sabedoria': 1, 'qualquer': 1, 'produtiva': 2, 'deve': 3, 'aprender': 1, 'ninguém': 1, 'ilha': 1, 'somos': 4, 'parte': 1, 'corpo': 1, '“não': 2, 'podem': 5, 'olhos': 1, 'dizer': 2, 'mão:': 1, 'precisamos': 3, 'ti”': 1, '1': 5, 'coríntios': 4, '1221': 1, 'puder': 2, 'ir': 1, 'além': 1, 'ouço': 1, 'apóstolo': 3, 'paulo': 2, 'falando': 2, 'meus': 2, 'ouvidos:': 1, '“piper': 1, 'tem': 1, 'lhe': 1, 'foi': 3, 'dado': 2, 'gloria': 1, 'fosse': 1, 'dom”': 1, 'veja': 1, '47': 1, 'escuto': 1, 'dizer:': 1, '“trabalhei': 1, 'todos': 11, 'eles;': 1, 'todavia': 1, 'graça': 2, 'comigo”': 1, '1510': 1, 'quer': 1, 'receber': 1, 'crédito': 1, 'algum': 2, 'pela': 4, 'dele': 3, 'mesmo': 1, 'caminho': 2, 'percebo': 1, 'esposa': 2, 'me': 11, 'apoiou': 1, 'forma': 4, 'espetacular': 1, 'durante': 2, '52': 1, 'anos': 8, 'jamais': 3, 'reclamou': 1, 'paro': 1, 'penso:': 1, '“você': 4, 'está': 6, 'exagerando': 1, 'piper”': 1, 'minha': 9, 'memória': 1, 'fraca': 1, 'devem': 1, 'desconto': 1, 'pelo': 2, 'lembro': 1, 'nöel': 1, 'criticou': 1, 'seja': 4, 'gentil': 1, 'furiosamente': 1, 'estudar': 1, 'escrever': 2, 'falar': 3, 'maneira': 1, 'faço': 2, 'consigo': 2, 'imaginar': 1, 'vida': 7, 'seria': 2, 'ela': 4, 'recentemente': 1, 'estive': 1, 'pensando': 1, 'olhando': 1, 'trás': 2, 'contemplando': 1, 'esses': 2, '50': 2, '60': 1, 'passaram': 1, 'pergunto:': 1, 'aconteceu': 1, 'livros': 3, 'sermões': 2, 'aulas': 1, 'tornaram': 1, 'reais': 1, 'alguns': 1, 'pensamentos': 3, 'encorajar': 1, 'outros': 2, 'estão': 3, 'céu': 2, 'junto': 1, 'comigo': 1, 'querem': 1, 'fruto': 1, 'produtivos': 1, 'enquanto': 3, 'caminham': 1, 'desperdiçar': 1, 'saiba': 2, 'tenha': 1, 'visão': 1, 'clara': 1, 'relação': 1, 'tudo': 3, 'existe': 2, 'incluindo': 3, 'poucas': 1, 'coisas': 8, 'foram': 1, 'tão': 2, 'úteis': 1, 'jonathan': 2, 'edwards': 2, 'chama': 1, '“o': 2, 'fim': 3, 'qual': 3, 'mundo”': 1, 'costumava': 1, 'carregar': 1, 'na': 8, 'carteira': 2, 'pedaço': 2, 'papel': 2, 'dizia:': 1, 'espalhar': 1, 'paixão': 1, 'supremacia': 2, 'todas': 5, 'alegria': 2, 'povos”': 2, 'nunca': 3, 'esqueci': 1, 'disso': 1, 'carregue': 1, 'consciência': 1, 'horas': 3, 'nesse': 1, 'planeta': 1, 'essa': 8, 'coisa': 3, '2': 1, 'abrace': 1, 'subcriador': 1, 'mim': 3, 'animador': 1, 'perceber': 2, 'huma ...

# %% [markdown]
# #**Exibição dos Resultados I**
#
# * Código sem a limitação para os termos.

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências

plt.figure(figsize=(22,12))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()

# %% [markdown]
# #**Exibição dos Resultados II**
#
# * Código com a limitação para os termos.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências
df = df.iloc[np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(22,12))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if __name__ == '__main__':
